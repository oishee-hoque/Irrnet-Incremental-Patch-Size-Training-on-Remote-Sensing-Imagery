# %% [markdown]
# ### Dataset_Prep

# %%
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt
import segmentation_models as sm
import tensorflow as tf
import keras
from keras.metrics import MeanIoU
import random
import glob
from sklearn.preprocessing import MinMaxScaler
import numpy as np
# from keras.applications.resnet50 import preprocess_input, decode_predictions
BACKBONE = 'resnet50'
preprocess_input = sm.get_preprocessing(BACKBONE)
# preprocess_input = keras.applications.resnet_v2.preprocess_input()

# %%
train_imgs = np.load('data/train_img_128.npy')
train_msks = np.load('data/train_msk_128.npy')
val_imgs = np.load('data/val_img_128.npy')
val_msks = np.load('data/val_msk_128.npy')

# print(train_imgs.shape)
# train_imgs=np.append(train_imgs,val_imgs[500:-1,:,:,:]).reshape(-1,128, 128, 7)
# train_msks=np.append(train_msks,val_msks[500:-1,:,:,:]).reshape(-1,128, 128, 3)

# val_imgs=val_imgs[0:500,:,:,:]
# val_msks=val_msks[0:500,:,:,:]
# print(train_imgs.shape)
# print(len(train_imgs),len(val_imgs))

# %%
val_imgs.shape
# Out:
# (799, 128, 128, 7)

# %%
class Augment(keras.layers.Layer):
    def __init__(self, seed=42):
        super().__init__()
        # both use the same seed, so they'll make the same random changes.
        self.augment_inputs = keras.Sequential([
                  keras.layers.RandomFlip("horizontal_and_vertical",seed=42),
                  keras.layers.RandomRotation(factor=(-0.2, 0.3) ,seed=42),
                  # keras.layers.RandomZoom(height_factor=(0.2, 0.3), seed=42),  # Zoom in/out 20%
                  # keras.layers.RandomBrightness(0.2,value_range=(0, 1), seed=42),  # Adjust contrast by 10%
                  keras.layers.RandomContrast(0.2, seed=42),
                  # keras.layers.RandomTranslation(0.05,0.05,seed=42)
                ])

        
        # Use the same seed to keep inputs and labels transformations consistent
        self.augment_labels = keras.Sequential([
                  keras.layers.RandomFlip("horizontal_and_vertical",seed=42),
                  keras.layers.RandomRotation(factor=(-0.2, 0.3),seed=42),
                  # keras.layers.RandomZoom(height_factor=(0.2, 0.3), seed=42),  # Zoom in/out 20%
                  # keras.layers.RandomTranslation(0.05,0.05,seed=42)
                ])

    def call(self, inputs, labels):
        inputs = self.augment_inputs(inputs)
        labels_1 = self.augment_labels(labels)
        return inputs,labels_1

# %%
def preprocess_data(img, mask, channel = 3, join=False):
    img = preprocess_input(img)
    print(img.shape)
    print(mask.shape)
    if(join == 'jbinary'):
        mask1= mask[:,:,0] + mask[:,:,1]
        mask_2 = tf.one_hot(tf.cast(mask1, tf.int32), depth=2)
        mask = (mask,mask_2)
        
    return img, mask

def prep(data, ch, target_size=(64, 64)):
    img_dataset = tf.data.Dataset.from_tensor_slices(data)
    
    def resize_image(image):
        image = tf.image.resize(image, target_size)
        image = tf.ensure_shape(image, (target_size[0], target_size[1], ch))
        return image

    img_dataset = img_dataset.map(resize_image)
    
    for img in img_dataset.take(1):
        print(img.shape)
    
    return img_dataset
    

def trainGenerator(img_array, mask_array, batch_size, seed=None, eval_set=False,bands=6,target_size=(128, 128)):
    img_dataset = prep(img_array[:,:,:,:bands],bands,target_size)
    mask_dataset = prep(mask_array[:,:,:,:3],3,target_size)

    dataset = tf.data.Dataset.zip((img_dataset, mask_dataset))

    dataset_1 = dataset.map(lambda img, mask: preprocess_data(img, mask, 3, False), num_parallel_calls=tf.data.AUTOTUNE)

    # Continue with batching, repeating, etc.
    if eval_set!=True:
        dataset_1 = dataset_1.batch(batch_size).repeat().map(Augment()).prefetch(tf.data.AUTOTUNE)
    else:
        dataset_1 = dataset_1.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    return dataset_1

train_img_gen = trainGenerator(train_imgs,train_msks,batch_size=16,bands=3,target_size=(128, 128))
valid_img_gen = trainGenerator(val_imgs,val_msks,batch_size=16,eval_set=True,bands=3,target_size=(128, 128))
# Out:
# (128, 128, 6)
# (128, 128, 3)
# (128, 128, 6)
# (128, 128, 3)
# (128, 128, 6)
# (128, 128, 3)
# (128, 128, 6)
# (128, 128, 3)

# %%
train_img_gen

# %%
valid_img_gen

# %% [markdown]
# ###### ResNet50V2

# %%
batch_size = 16

steps_per_epoch = len(train_imgs)//batch_size
val_steps_per_epoch = len(val_imgs)//batch_size
mIou = keras.metrics.OneHotMeanIoU(num_classes=3)
IMG_HEIGHT = 128
IMG_WIDTH = 128
IMG_CHANNELS = 6
n_classes = 3

# %%
import tensorflow as tf

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    """
    Compute the Dice coefficient between tensors of true and predicted labels.
    
    :param y_true: tensor of true labels, one-hot encoded.
    :param y_pred: tensor of predicted labels.
    :param smooth: small constant to avoid division by zero.
    :return: Dice coefficient.
    """
    # Compute the intersection
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    # Compute the union
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3])
    # Compute the Dice coefficient
    dice = (2. * intersection + smooth) / (union + smooth)
    # Return the mean over the batch
    return tf.reduce_mean(dice)

def dice_loss(y_true, y_pred):
    """
    Compute the Dice loss, which is 1 minus the Dice coefficient.
    
    :param y_true: tensor of true labels, one-hot encoded.
    :param y_pred: tensor of predicted labels.
    :return: Dice loss.
    """
    return 1 - dice_coefficient(y_true, y_pred)
import tensorflow as tf

def mIoU(y_true, y_pred):
    """
    Calculate mean Intersection-Over-Union (mIOU) for one-hot encoded segmentation masks.
    
    :param y_true: The ground truth segmentation mask, one-hot encoded.
    :param y_pred: The predicted segmentation mask, before softmax or after argmax to one-hot encode.
    :param num_classes: The number of classes.
    :return: The mean IOU score.
    """
    # # If y_pred is not one-hot encoded (e.g., from a softmax layer), convert it using argmax
    # y_pred = tf.argmax(y_pred, axis=-1)
    # y_pred = tf.one_hot(y_pred, depth=num_classes)
    
    # Ensure the predictions are of type float32
    y_pred = tf.cast(y_pred, tf.float32)
    y_true = tf.cast(y_true, tf.float32)
    
    # Calculate IOU for each class
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true, axis=[1, 2]) + tf.reduce_sum(y_pred, axis=[1, 2]) - intersection
    
    # Smooth to avoid division by zero
    iou = (intersection + 1e-7) / (union + 1e-7)
    
    # Calculate mean IOU across all classes
    mean_iou = tf.reduce_mean(iou, axis=-1)
    
    return mean_iou


def data_prep(y_true, y_pred,num_classes=2):
    # Calculate per-class TP, FP, and FN
    tp = tf.reduce_sum(y_true * y_pred, axis=[0, 1, 2])
    fp = tf.reduce_sum((1 - y_true) * y_pred, axis=[0, 1, 2])
    fn = tf.reduce_sum(y_true * (1 - y_pred), axis=[0, 1, 2])

  
    return tp, fp, fn
    
def pre_cal(y_true, y_pred,num_classes=2):
    tp, fp, fn = data_prep(y_true, y_pred,num_classes)
    precision = tp / (tp + fp + 1e-5)
    return precision
    
def rec_cal(y_true, y_pred,num_classes=2):
    tp, fp, fn = data_prep(y_true, y_pred,num_classes)
    recall = tp / (tp + fn + 1e-5)
    return recall
    
def f1_score(y_true, y_pred,num_classes=2):
    precision =  pre_cal(y_true, y_pred,num_classes)
    recall = rec_cal(y_true, y_pred,num_classes)
    f1_scores = 2 * ((precision * recall) / (precision + recall + 1e-5)) 
    return f1_scores
    
def precision_0(y_true, y_pred,num_classes=2):
    precision =  pre_cal(y_true, y_pred,num_classes)
    return precision[0]
    
def precision_1(y_true, y_pred,num_classes=2):
    precision =  pre_cal(y_true, y_pred,num_classes)
    return precision[1]
    
def precision_2(y_true, y_pred,num_classes=2):
    precision =  pre_cal(y_true, y_pred,num_classes)
    return precision[2]
    
def recall_0(y_true, y_pred,num_classes=2):
    recall = rec_cal(y_true, y_pred,num_classes)
    return recall[0]
    
def recall_1(y_true, y_pred,num_classes=2):
    recall = rec_cal(y_true, y_pred,num_classes)
    return recall[1]
    
def recall_2(y_true, y_pred,num_classes=2):
    recall = rec_cal(y_true, y_pred,num_classes)
    return recall[2]

    
def f1_score0(y_true, y_pred,num_classes=2):
    f1_scores=f1_score(y_true, y_pred,num_classes)
    return f1_scores[0]

    
def f1_score1(y_true, y_pred,num_classes=2):
    f1_scores=f1_score(y_true, y_pred,num_classes)
    return f1_scores[1]

    
def f1_score2(y_true, y_pred,num_classes=2):
    f1_scores=f1_score(y_true, y_pred,num_classes)
    return f1_scores[2]

def binary_crossentropy_1(y_true, y_pred, epsilon=1e-7):
    y_pred = tf.clip_by_value(y_pred, epsilon, 1 - epsilon)  # Clip predictions to avoid log(0)
    bce = -y_true * tf.math.log(y_pred) - (1 - y_true) * tf.math.log(1 - y_pred)
    return tf.reduce_mean(bce)  # Return the mean Binary Crossentropy loss

def bce_dice_loss(y_true, y_pred):
    bce = binary_crossentropy_1(y_true, y_pred)
    dice = dice_loss(y_true, y_pred)
    # Combining BCE and Dice loss
    return bce + dice

# %%
from keras.layers import Input, Conv2D
from keras.models import Model
BACKBONE = 'resnet50'
model = sm.Unet(BACKBONE, encoder_weights='imagenet', 
                input_shape=(IMG_HEIGHT, IMG_WIDTH, 3),
                classes=n_classes, activation='softmax')

inp = Input(shape=(None, None, 6))
l1 = Conv2D(3, (1, 1))(inp) # map N channels data to 3 channels
out = model(l1)

model = Model(inp, out, name=model.name)

# %%
model.load_weights('/scratch/gza5dr/IrrigationTypeDetection/Experinments/proposed_experiment/model_ckpt/21_res50_16_64_21ch.keras')

# %%
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=5, min_lr=0.00000001)
checkpoint_filepath = 'model_ckpt/21_res50_16_64_21ch.keras'
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
model.compile(optimizer=keras.optimizers.Adam(learning_rate=.00004), loss=bce_dice_loss, 
                                              metrics=['accuracy','precision','recall',mIoU,
                                              f1_score,f1_score0,f1_score1,f1_score2,
                                              precision_0,precision_1,precision_2,recall_0,recall_1,recall_2])

# %%
history=model.fit(train_img_gen,
          steps_per_epoch=steps_per_epoch,
          epochs=30,
          verbose=2,
          validation_data=valid_img_gen,
          validation_steps=val_steps_per_epoch,callbacks=[reduce_lr,model_checkpoint_callback])
# Out:
# Epoch 1/30
# 2024-03-24 21:59:09.298641: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x555f967f7fc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-03-24 21:59:09.298687: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100-SXM4-80GB, Compute Capability 8.0
# 2024-03-24 21:59:10.235202: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-03-24 21:59:12.807616: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8904
# 2024-03-24 21:59:42.015409: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 43/43 - 87s - 2s/step - accuracy: 0.6780 - f1_score: 0.5880 - f1_score0: 0.4919 - f1_score1: 0.5091 - f1_score2: 0.7631 - loss: 0.8602 - m_io_u: 0.3761 - precision: 0.7219 - precision_0: 0.5038 - precision_1: 0.5252 - precision_2: 0.7482 - recall: 0.6276 - recall_0: 0.4913 - recall_1: 0.5078 - recall_2: 0.7810 - val_accuracy: 0.6176 - val_f1_score: 0.5430 - val_f1_score0: 0.3310 - val_f1_score1: 0.5162 - val_f1_score2: 0.7819 - val_loss: 1.0779 - val_m_io_u: 0.3682 - val_precision: 0.6283 - val_precision_0: 0.5615 - val_precision_1: 0.3882 - val_precision_2: 0.8094 - val_recall: 0.6015 - val_recall_0: 0.2361 - val_recall_1: 0.7870 - val_recall_2: 0.7579 - learning_rate: 4.0000e-05
# Epoch 2/30
# 2024-03-24 22:00:37.428897: I tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:328] ptxas warning : Registers are spilled to local memory in function 'fusion_421', 76 bytes spill stores, 76 bytes spill loads
#
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 43/43 - 60s - 1s/step - accuracy: 0.7129 - f1_score: 0.6179 - f1_score0: 0.5282 - f1_score1: 0.5504 - f1_score2: 0.7750 - loss: 0.7700 - m_io_u: 0.3946 - precision: 0.7597 - precision_0: 0.5387 - precision_1: 0.5678 - precision_2: 0.7600 - recall: 0.6604 - recall_0: 0.5292 - recall_1: 0.5476 - recall_2: 0.7928 - val_accuracy: 0.6285 - val_f1_score: 0.5641 - val_f1_score0: 0.4718 - val_f1_score1: 0.4877 - val_f1_score2: 0.7328 - val_loss: 0.9799 - val_m_io_u: 0.3802 - val_precision: 0.6412 - val_precision_0: 0.4197 - val_precision_1: 0.4279 - val_precision_2: 0.8577 - val_recall: 0.6087 - val_recall_0: 0.5387 - val_recall_1: 0.5670 - val_recall_2: 0.6396 - learning_rate: 4.0000e-05
# Epoch 3/30
# 43/43 - 27s - 621ms/step - accuracy: 0.7275 - f1_score: 0.6319 - f1_score0: 0.5432 - f1_score1: 0.5734 - f1_score2: 0.7791 - loss: 0.7399 - m_io_u: 0.4022 - precision: 0.7738 - precision_0: 0.5494 - precision_1: 0.5940 - precision_2: 0.7656 - recall: 0.6760 - recall_0: 0.5481 - recall_1: 0.5673 - recall_2: 0.7954 - val_accuracy: 0.7176 - val_f1_score: 0.6444 - val_f1_score0: 0.5994 - val_f1_score1: 0.5466 - val_f1_score2: 0.7873 - val_loss: 0.7872 - val_m_io_u: 0.4189 - val_precision: 0.7280 - val_precision_0: 0.5681 - val_precision_1: 0.5858 - val_precision_2: 0.7988 - val_recall: 0.7050 - val_recall_0: 0.6368 - val_recall_1: 0.5157 - val_recall_2: 0.7774 - learning_rate: 4.0000e-05
# Epoch 4/30
# 43/43 - 27s - 624ms/step - accuracy: 0.7316 - f1_score: 0.6382 - f1_score0: 0.5526 - f1_score1: 0.5795 - f1_score2: 0.7824 - loss: 0.7272 - m_io_u: 0.4073 - precision: 0.7780 - precision_0: 0.5628 - precision_1: 0.5952 - precision_2: 0.7691 - recall: 0.6803 - recall_0: 0.5544 - recall_1: 0.5786 - recall_2: 0.7985 - val_accuracy: 0.7251 - val_f1_score: 0.6286 - val_f1_score0: 0.5226 - val_f1_score1: 0.5373 - val_f1_score2: 0.8260 - val_loss: 0.7297 - val_m_io_u: 0.4264 - val_precision: 0.7432 - val_precision_0: 0.4690 - val_precision_1: 0.6029 - val_precision_2: 0.8400 - val_recall: 0.7074 - val_recall_0: 0.5901 - val_recall_1: 0.4846 - val_recall_2: 0.8125 - learning_rate: 4.0000e-05
# Epoch 5/30
# 43/43 - 27s - 625ms/step - accuracy: 0.7391 - f1_score: 0.6464 - f1_score0: 0.5627 - f1_score1: 0.5913 - f1_score2: 0.7853 - loss: 0.7104 - m_io_u: 0.4121 - precision: 0.7851 - precision_0: 0.5716 - precision_1: 0.6059 - precision_2: 0.7733 - recall: 0.6889 - recall_0: 0.5657 - recall_1: 0.5913 - recall_2: 0.8001 - val_accuracy: 0.7241 - val_f1_score: 0.6430 - val_f1_score0: 0.6029 - val_f1_score1: 0.5315 - val_f1_score2: 0.7947 - val_loss: 0.7711 - val_m_io_u: 0.4189 - val_precision: 0.7356 - val_precision_0: 0.5751 - val_precision_1: 0.6056 - val_precision_2: 0.7871 - val_recall: 0.7102 - val_recall_0: 0.6355 - val_recall_1: 0.4769 - val_recall_2: 0.8035 - learning_rate: 4.0000e-05
# Epoch 6/30
# 43/43 - 27s - 622ms/step - accuracy: 0.7461 - f1_score: 0.6547 - f1_score0: 0.5740 - f1_score1: 0.6008 - f1_score2: 0.7895 - loss: 0.6967 - m_io_u: 0.4170 - precision: 0.7908 - precision_0: 0.5845 - precision_1: 0.6137 - precision_2: 0.7770 - recall: 0.6976 - recall_0: 0.5751 - recall_1: 0.6021 - recall_2: 0.8045 - val_accuracy: 0.6918 - val_f1_score: 0.5922 - val_f1_score0: 0.4918 - val_f1_score1: 0.4675 - val_f1_score2: 0.8173 - val_loss: 0.7832 - val_m_io_u: 0.4038 - val_precision: 0.7056 - val_precision_0: 0.4217 - val_precision_1: 0.5917 - val_precision_2: 0.8312 - val_recall: 0.6737 - val_recall_0: 0.5900 - val_recall_1: 0.3864 - val_recall_2: 0.8039 - learning_rate: 4.0000e-05
# Epoch 7/30
# 43/43 - 28s - 649ms/step - accuracy: 0.7483 - f1_score: 0.6593 - f1_score0: 0.5787 - f1_score1: 0.6083 - f1_score2: 0.7910 - loss: 0.6888 - m_io_u: 0.4203 - precision: 0.7930 - precision_0: 0.5883 - precision_1: 0.6204 - precision_2: 0.7802 - recall: 0.6998 - recall_0: 0.5813 - recall_1: 0.6117 - recall_2: 0.8042 - val_accuracy: 0.7198 - val_f1_score: 0.6337 - val_f1_score0: 0.5822 - val_f1_score1: 0.5289 - val_f1_score2: 0.7899 - val_loss: 0.7619 - val_m_io_u: 0.4124 - val_precision: 0.7361 - val_precision_0: 0.5676 - val_precision_1: 0.5642 - val_precision_2: 0.7865 - val_recall: 0.6998 - val_recall_0: 0.5995 - val_recall_1: 0.5019 - val_recall_2: 0.7943 - learning_rate: 4.0000e-05
# Epoch 8/30
# 43/43 - 28s - 647ms/step - accuracy: 0.7547 - f1_score: 0.6659 - f1_score0: 0.5885 - f1_score1: 0.6169 - f1_score2: 0.7924 - loss: 0.6763 - m_io_u: 0.4241 - precision: 0.7995 - precision_0: 0.5983 - precision_1: 0.6279 - precision_2: 0.7814 - recall: 0.7061 - recall_0: 0.5902 - recall_1: 0.6205 - recall_2: 0.8058 - val_accuracy: 0.7402 - val_f1_score: 0.6103 - val_f1_score0: 0.4446 - val_f1_score1: 0.5610 - val_f1_score2: 0.8253 - val_loss: 0.7078 - val_m_io_u: 0.4292 - val_precision: 0.7673 - val_precision_0: 0.4809 - val_precision_1: 0.5279 - val_precision_2: 0.8225 - val_recall: 0.7082 - val_recall_0: 0.4135 - val_recall_1: 0.5986 - val_recall_2: 0.8280 - learning_rate: 4.0000e-05
# Epoch 9/30
# 43/43 - 27s - 627ms/step - accuracy: 0.7568 - f1_score: 0.6695 - f1_score0: 0.5920 - f1_score1: 0.6223 - f1_score2: 0.7941 - loss: 0.6704 - m_io_u: 0.4269 - precision: 0.8015 - precision_0: 0.6016 - precision_1: 0.6330 - precision_2: 0.7836 - recall: 0.7086 - recall_0: 0.5942 - recall_1: 0.6259 - recall_2: 0.8071 - val_accuracy: 0.7200 - val_f1_score: 0.6255 - val_f1_score0: 0.5838 - val_f1_score1: 0.4945 - val_f1_score2: 0.7982 - val_loss: 0.7643 - val_m_io_u: 0.4101 - val_precision: 0.7346 - val_precision_0: 0.5665 - val_precision_1: 0.5737 - val_precision_2: 0.7772 - val_recall: 0.7013 - val_recall_0: 0.6045 - val_recall_1: 0.4367 - val_recall_2: 0.8216 - learning_rate: 4.0000e-05
# Epoch 10/30
# 43/43 - 27s - 623ms/step - accuracy: 0.7638 - f1_score: 0.6776 - f1_score0: 0.6035 - f1_score1: 0.6330 - f1_score2: 0.7962 - loss: 0.6580 - m_io_u: 0.4321 - precision: 0.8084 - precision_0: 0.6145 - precision_1: 0.6415 - precision_2: 0.7851 - recall: 0.7159 - recall_0: 0.6023 - recall_1: 0.6381 - recall_2: 0.8095 - val_accuracy: 0.6783 - val_f1_score: 0.5767 - val_f1_score0: 0.4977 - val_f1_score1: 0.4213 - val_f1_score2: 0.8112 - val_loss: 0.8097 - val_m_io_u: 0.3926 - val_precision: 0.6910 - val_precision_0: 0.4120 - val_precision_1: 0.5358 - val_precision_2: 0.8490 - val_recall: 0.6603 - val_recall_0: 0.6283 - val_recall_1: 0.3471 - val_recall_2: 0.7767 - learning_rate: 4.0000e-05
# Epoch 11/30
# 43/43 - 28s - 646ms/step - accuracy: 0.7670 - f1_score: 0.6814 - f1_score0: 0.6080 - f1_score1: 0.6372 - f1_score2: 0.7988 - loss: 0.6492 - m_io_u: 0.4348 - precision: 0.8115 - precision_0: 0.6168 - precision_1: 0.6459 - precision_2: 0.7897 - recall: 0.7192 - recall_0: 0.6108 - recall_1: 0.6426 - recall_2: 0.8102 - val_accuracy: 0.7228 - val_f1_score: 0.6325 - val_f1_score0: 0.6012 - val_f1_score1: 0.5054 - val_f1_score2: 0.7909 - val_loss: 0.7544 - val_m_io_u: 0.4117 - val_precision: 0.7364 - val_precision_0: 0.5631 - val_precision_1: 0.5906 - val_precision_2: 0.7893 - val_recall: 0.7059 - val_recall_0: 0.6481 - val_recall_1: 0.4454 - val_recall_2: 0.7940 - learning_rate: 4.0000e-05
# Epoch 12/30
# 43/43 - 27s - 626ms/step - accuracy: 0.7688 - f1_score: 0.6840 - f1_score0: 0.6089 - f1_score1: 0.6429 - f1_score2: 0.8003 - loss: 0.6470 - m_io_u: 0.4372 - precision: 0.8126 - precision_0: 0.6172 - precision_1: 0.6502 - precision_2: 0.7923 - recall: 0.7218 - recall_0: 0.6123 - recall_1: 0.6496 - recall_2: 0.8104 - val_accuracy: 0.6873 - val_f1_score: 0.5826 - val_f1_score0: 0.4849 - val_f1_score1: 0.4575 - val_f1_score2: 0.8055 - val_loss: 0.8053 - val_m_io_u: 0.4031 - val_precision: 0.7048 - val_precision_0: 0.4162 - val_precision_1: 0.5178 - val_precision_2: 0.8440 - val_recall: 0.6671 - val_recall_0: 0.5807 - val_recall_1: 0.4099 - val_recall_2: 0.7705 - learning_rate: 4.0000e-05
# Epoch 13/30
# 43/43 - 28s - 648ms/step - accuracy: 0.7700 - f1_score: 0.6879 - f1_score0: 0.6143 - f1_score1: 0.6485 - f1_score2: 0.8008 - loss: 0.6409 - m_io_u: 0.4392 - precision: 0.8140 - precision_0: 0.6231 - precision_1: 0.6564 - precision_2: 0.7919 - recall: 0.7235 - recall_0: 0.6170 - recall_1: 0.6543 - recall_2: 0.8119 - val_accuracy: 0.7052 - val_f1_score: 0.6115 - val_f1_score0: 0.6047 - val_f1_score1: 0.4457 - val_f1_score2: 0.7840 - val_loss: 0.8034 - val_m_io_u: 0.4019 - val_precision: 0.7151 - val_precision_0: 0.5289 - val_precision_1: 0.6126 - val_precision_2: 0.8000 - val_recall: 0.6919 - val_recall_0: 0.7098 - val_recall_1: 0.3528 - val_recall_2: 0.7702 - learning_rate: 4.0000e-05
# Epoch 14/30
# 43/43 - 27s - 624ms/step - accuracy: 0.7754 - f1_score: 0.6932 - f1_score0: 0.6251 - f1_score1: 0.6521 - f1_score2: 0.8024 - loss: 0.6280 - m_io_u: 0.4436 - precision: 0.8191 - precision_0: 0.6282 - precision_1: 0.6615 - precision_2: 0.7960 - recall: 0.7289 - recall_0: 0.6320 - recall_1: 0.6551 - recall_2: 0.8108 - val_accuracy: 0.6901 - val_f1_score: 0.5886 - val_f1_score0: 0.5044 - val_f1_score1: 0.4581 - val_f1_score2: 0.8033 - val_loss: 0.8126 - val_m_io_u: 0.4029 - val_precision: 0.7027 - val_precision_0: 0.4175 - val_precision_1: 0.5547 - val_precision_2: 0.8519 - val_recall: 0.6735 - val_recall_0: 0.6368 - val_recall_1: 0.3902 - val_recall_2: 0.7600 - learning_rate: 8.0000e-06
# Epoch 15/30
# 2024-03-24 22:06:41.252630: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 6712907046813220977
# 2024-03-24 22:06:41.252703: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 6670235632506235738
# 43/43 - 28s - 648ms/step - accuracy: 0.7775 - f1_score: 0.6947 - f1_score0: 0.6248 - f1_score1: 0.6556 - f1_score2: 0.8036 - loss: 0.6232 - m_io_u: 0.4445 - precision: 0.8222 - precision_0: 0.6323 - precision_1: 0.6621 - precision_2: 0.7951 - recall: 0.7296 - recall_0: 0.6267 - recall_1: 0.6620 - recall_2: 0.8140 - val_accuracy: 0.7277 - val_f1_score: 0.6343 - val_f1_score0: 0.5911 - val_f1_score1: 0.5204 - val_f1_score2: 0.7915 - val_loss: 0.7386 - val_m_io_u: 0.4154 - val_precision: 0.7439 - val_precision_0: 0.5625 - val_precision_1: 0.5886 - val_precision_2: 0.7870 - val_recall: 0.7076 - val_recall_0: 0.6256 - val_recall_1: 0.4701 - val_recall_2: 0.7973 - learning_rate: 8.0000e-06
# Epoch 16/30
# 43/43 - 27s - 626ms/step - accuracy: 0.7799 - f1_score: 0.6981 - f1_score0: 0.6311 - f1_score1: 0.6589 - f1_score2: 0.8043 - loss: 0.6185 - m_io_u: 0.4471 - precision: 0.8241 - precision_0: 0.6381 - precision_1: 0.6648 - precision_2: 0.7963 - recall: 0.7330 - recall_0: 0.6331 - recall_1: 0.6647 - recall_2: 0.8144 - val_accuracy: 0.6907 - val_f1_score: 0.5892 - val_f1_score0: 0.4925 - val_f1_score1: 0.4731 - val_f1_score2: 0.8019 - val_loss: 0.8013 - val_m_io_u: 0.4051 - val_precision: 0.7025 - val_precision_0: 0.4160 - val_precision_1: 0.5575 - val_precision_2: 0.8411 - val_recall: 0.6745 - val_recall_0: 0.6034 - val_recall_1: 0.4109 - val_recall_2: 0.7662 - learning_rate: 8.0000e-06
# Epoch 17/30
# 43/43 - 28s - 650ms/step - accuracy: 0.7787 - f1_score: 0.6966 - f1_score0: 0.6265 - f1_score1: 0.6575 - f1_score2: 0.8058 - loss: 0.6206 - m_io_u: 0.4461 - precision: 0.8224 - precision_0: 0.6306 - precision_1: 0.6647 - precision_2: 0.7994 - recall: 0.7322 - recall_0: 0.6317 - recall_1: 0.6621 - recall_2: 0.8141 - val_accuracy: 0.7309 - val_f1_score: 0.6390 - val_f1_score0: 0.5884 - val_f1_score1: 0.5353 - val_f1_score2: 0.7933 - val_loss: 0.7283 - val_m_io_u: 0.4175 - val_precision: 0.7472 - val_precision_0: 0.5733 - val_precision_1: 0.5844 - val_precision_2: 0.7844 - val_recall: 0.7112 - val_recall_0: 0.6068 - val_recall_1: 0.4975 - val_recall_2: 0.8036 - learning_rate: 8.0000e-06
# Epoch 18/30
# 43/43 - 27s - 623ms/step - accuracy: 0.7805 - f1_score: 0.6989 - f1_score0: 0.6298 - f1_score1: 0.6616 - f1_score2: 0.8053 - loss: 0.6178 - m_io_u: 0.4479 - precision: 0.8239 - precision_0: 0.6362 - precision_1: 0.6678 - precision_2: 0.7979 - recall: 0.7343 - recall_0: 0.6335 - recall_1: 0.6683 - recall_2: 0.8147 - val_accuracy: 0.7101 - val_f1_score: 0.6016 - val_f1_score0: 0.4992 - val_f1_score1: 0.4892 - val_f1_score2: 0.8165 - val_loss: 0.7591 - val_m_io_u: 0.4161 - val_precision: 0.7241 - val_precision_0: 0.4341 - val_precision_1: 0.5665 - val_precision_2: 0.8407 - val_recall: 0.6924 - val_recall_0: 0.5873 - val_recall_1: 0.4304 - val_recall_2: 0.7937 - learning_rate: 8.0000e-06
# Epoch 19/30
# 43/43 - 28s - 649ms/step - accuracy: 0.7823 - f1_score: 0.7007 - f1_score0: 0.6310 - f1_score1: 0.6652 - f1_score2: 0.8060 - loss: 0.6139 - m_io_u: 0.4501 - precision: 0.8258 - precision_0: 0.6342 - precision_1: 0.6756 - precision_2: 0.7980 - recall: 0.7361 - recall_0: 0.6370 - recall_1: 0.6669 - recall_2: 0.8160 - val_accuracy: 0.7335 - val_f1_score: 0.6406 - val_f1_score0: 0.5845 - val_f1_score1: 0.5406 - val_f1_score2: 0.7965 - val_loss: 0.7247 - val_m_io_u: 0.4188 - val_precision: 0.7503 - val_precision_0: 0.5818 - val_precision_1: 0.5806 - val_precision_2: 0.7809 - val_recall: 0.7132 - val_recall_0: 0.5891 - val_recall_1: 0.5096 - val_recall_2: 0.8138 - learning_rate: 1.6000e-06
# Epoch 20/30
# 43/43 - 27s - 621ms/step - accuracy: 0.7813 - f1_score: 0.7002 - f1_score0: 0.6296 - f1_score1: 0.6646 - f1_score2: 0.8064 - loss: 0.6144 - m_io_u: 0.4487 - precision: 0.8248 - precision_0: 0.6340 - precision_1: 0.6742 - precision_2: 0.7980 - recall: 0.7348 - recall_0: 0.6350 - recall_1: 0.6671 - recall_2: 0.8168 - val_accuracy: 0.7092 - val_f1_score: 0.6017 - val_f1_score0: 0.4951 - val_f1_score1: 0.4967 - val_f1_score2: 0.8134 - val_loss: 0.7606 - val_m_io_u: 0.4139 - val_precision: 0.7248 - val_precision_0: 0.4332 - val_precision_1: 0.5676 - val_precision_2: 0.8371 - val_recall: 0.6901 - val_recall_0: 0.5777 - val_recall_1: 0.4416 - val_recall_2: 0.7911 - learning_rate: 1.6000e-06
# Epoch 21/30
# 43/43 - 28s - 649ms/step - accuracy: 0.7839 - f1_score: 0.7023 - f1_score0: 0.6325 - f1_score1: 0.6680 - f1_score2: 0.8063 - loss: 0.6104 - m_io_u: 0.4496 - precision: 0.8275 - precision_0: 0.6346 - precision_1: 0.6797 - precision_2: 0.7983 - recall: 0.7375 - recall_0: 0.6396 - recall_1: 0.6670 - recall_2: 0.8165 - val_accuracy: 0.7351 - val_f1_score: 0.6426 - val_f1_score0: 0.5851 - val_f1_score1: 0.5454 - val_f1_score2: 0.7973 - val_loss: 0.7190 - val_m_io_u: 0.4202 - val_precision: 0.7524 - val_precision_0: 0.5858 - val_precision_1: 0.5811 - val_precision_2: 0.7809 - val_recall: 0.7144 - val_recall_0: 0.5861 - val_recall_1: 0.5172 - val_recall_2: 0.8155 - learning_rate: 1.6000e-06
# Epoch 22/30
# 43/43 - 27s - 624ms/step - accuracy: 0.7840 - f1_score: 0.7023 - f1_score0: 0.6351 - f1_score1: 0.6653 - f1_score2: 0.8065 - loss: 0.6112 - m_io_u: 0.4501 - precision: 0.8273 - precision_0: 0.6414 - precision_1: 0.6710 - precision_2: 0.7991 - recall: 0.7379 - recall_0: 0.6378 - recall_1: 0.6707 - recall_2: 0.8157 - val_accuracy: 0.7090 - val_f1_score: 0.6011 - val_f1_score0: 0.4910 - val_f1_score1: 0.5021 - val_f1_score2: 0.8102 - val_loss: 0.7614 - val_m_io_u: 0.4124 - val_precision: 0.7258 - val_precision_0: 0.4316 - val_precision_1: 0.5700 - val_precision_2: 0.8326 - val_recall: 0.6890 - val_recall_0: 0.5694 - val_recall_1: 0.4487 - val_recall_2: 0.7890 - learning_rate: 1.6000e-06
# Epoch 23/30
# 43/43 - 28s - 652ms/step - accuracy: 0.7836 - f1_score: 0.7021 - f1_score0: 0.6329 - f1_score1: 0.6667 - f1_score2: 0.8065 - loss: 0.6106 - m_io_u: 0.4513 - precision: 0.8269 - precision_0: 0.6368 - precision_1: 0.6763 - precision_2: 0.7984 - recall: 0.7374 - recall_0: 0.6384 - recall_1: 0.6690 - recall_2: 0.8166 - val_accuracy: 0.7360 - val_f1_score: 0.6435 - val_f1_score0: 0.5806 - val_f1_score1: 0.5519 - val_f1_score2: 0.7979 - val_loss: 0.7160 - val_m_io_u: 0.4209 - val_precision: 0.7541 - val_precision_0: 0.5907 - val_precision_1: 0.5736 - val_precision_2: 0.7807 - val_recall: 0.7147 - val_recall_0: 0.5724 - val_recall_1: 0.5351 - val_recall_2: 0.8169 - learning_rate: 1.6000e-06
# Epoch 24/30
# 43/43 - 27s - 623ms/step - accuracy: 0.7849 - f1_score: 0.7035 - f1_score0: 0.6345 - f1_score1: 0.6692 - f1_score2: 0.8070 - loss: 0.6082 - m_io_u: 0.4498 - precision: 0.8282 - precision_0: 0.6391 - precision_1: 0.6773 - precision_2: 0.7990 - recall: 0.7386 - recall_0: 0.6388 - recall_1: 0.6725 - recall_2: 0.8170 - val_accuracy: 0.7125 - val_f1_score: 0.6033 - val_f1_score0: 0.4898 - val_f1_score1: 0.5115 - val_f1_score2: 0.8087 - val_loss: 0.7564 - val_m_io_u: 0.4134 - val_precision: 0.7296 - val_precision_0: 0.4328 - val_precision_1: 0.5769 - val_precision_2: 0.8295 - val_recall: 0.6923 - val_recall_0: 0.5640 - val_recall_1: 0.4594 - val_recall_2: 0.7889 - learning_rate: 3.2000e-07
# Epoch 25/30
# 43/43 - 28s - 648ms/step - accuracy: 0.7839 - f1_score: 0.7026 - f1_score0: 0.6327 - f1_score1: 0.6681 - f1_score2: 0.8069 - loss: 0.6099 - m_io_u: 0.4505 - precision: 0.8274 - precision_0: 0.6358 - precision_1: 0.6765 - precision_2: 0.8000 - recall: 0.7377 - recall_0: 0.6386 - recall_1: 0.6706 - recall_2: 0.8158 - val_accuracy: 0.7364 - val_f1_score: 0.6437 - val_f1_score0: 0.5783 - val_f1_score1: 0.5544 - val_f1_score2: 0.7983 - val_loss: 0.7145 - val_m_io_u: 0.4212 - val_precision: 0.7549 - val_precision_0: 0.5934 - val_precision_1: 0.5712 - val_precision_2: 0.7799 - val_recall: 0.7148 - val_recall_0: 0.5656 - val_recall_1: 0.5421 - val_recall_2: 0.8185 - learning_rate: 3.2000e-07
# Epoch 26/30
# 43/43 - 27s - 620ms/step - accuracy: 0.7848 - f1_score: 0.7031 - f1_score0: 0.6335 - f1_score1: 0.6676 - f1_score2: 0.8083 - loss: 0.6069 - m_io_u: 0.4514 - precision: 0.8280 - precision_0: 0.6358 - precision_1: 0.6747 - precision_2: 0.8029 - recall: 0.7386 - recall_0: 0.6399 - recall_1: 0.6722 - recall_2: 0.8155 - val_accuracy: 0.7128 - val_f1_score: 0.6040 - val_f1_score0: 0.4905 - val_f1_score1: 0.5140 - val_f1_score2: 0.8075 - val_loss: 0.7571 - val_m_io_u: 0.4131 - val_precision: 0.7298 - val_precision_0: 0.4329 - val_precision_1: 0.5801 - val_precision_2: 0.8289 - val_recall: 0.6927 - val_recall_0: 0.5658 - val_recall_1: 0.4614 - val_recall_2: 0.7872 - learning_rate: 3.2000e-07
# Epoch 27/30
# 43/43 - 28s - 648ms/step - accuracy: 0.7828 - f1_score: 0.7016 - f1_score0: 0.6316 - f1_score1: 0.6668 - f1_score2: 0.8064 - loss: 0.6129 - m_io_u: 0.4501 - precision: 0.8265 - precision_0: 0.6366 - precision_1: 0.6756 - precision_2: 0.7981 - recall: 0.7366 - recall_0: 0.6360 - recall_1: 0.6696 - recall_2: 0.8166 - val_accuracy: 0.7365 - val_f1_score: 0.6437 - val_f1_score0: 0.5790 - val_f1_score1: 0.5539 - val_f1_score2: 0.7982 - val_loss: 0.7142 - val_m_io_u: 0.4212 - val_precision: 0.7549 - val_precision_0: 0.5930 - val_precision_1: 0.5724 - val_precision_2: 0.7796 - val_recall: 0.7150 - val_recall_0: 0.5671 - val_recall_1: 0.5399 - val_recall_2: 0.8185 - learning_rate: 3.2000e-07
# Epoch 28/30
# 43/43 - 27s - 627ms/step - accuracy: 0.7834 - f1_score: 0.7026 - f1_score0: 0.6335 - f1_score1: 0.6683 - f1_score2: 0.8062 - loss: 0.6107 - m_io_u: 0.4507 - precision: 0.8270 - precision_0: 0.6383 - precision_1: 0.6776 - precision_2: 0.7975 - recall: 0.7369 - recall_0: 0.6380 - recall_1: 0.6708 - recall_2: 0.8168 - val_accuracy: 0.7116 - val_f1_score: 0.6035 - val_f1_score0: 0.4904 - val_f1_score1: 0.5122 - val_f1_score2: 0.8078 - val_loss: 0.7589 - val_m_io_u: 0.4121 - val_precision: 0.7284 - val_precision_0: 0.4321 - val_precision_1: 0.5834 - val_precision_2: 0.8279 - val_recall: 0.6925 - val_recall_0: 0.5669 - val_recall_1: 0.4565 - val_recall_2: 0.7887 - learning_rate: 3.2000e-07
# Epoch 29/30
# 43/43 - 28s - 651ms/step - accuracy: 0.7845 - f1_score: 0.7033 - f1_score0: 0.6344 - f1_score1: 0.6678 - f1_score2: 0.8078 - loss: 0.6079 - m_io_u: 0.4509 - precision: 0.8278 - precision_0: 0.6379 - precision_1: 0.6775 - precision_2: 0.7999 - recall: 0.7384 - recall_0: 0.6399 - recall_1: 0.6698 - recall_2: 0.8179 - val_accuracy: 0.7367 - val_f1_score: 0.6436 - val_f1_score0: 0.5788 - val_f1_score1: 0.5538 - val_f1_score2: 0.7982 - val_loss: 0.7136 - val_m_io_u: 0.4212 - val_precision: 0.7552 - val_precision_0: 0.5934 - val_precision_1: 0.5730 - val_precision_2: 0.7789 - val_recall: 0.7152 - val_recall_0: 0.5664 - val_recall_1: 0.5391 - val_recall_2: 0.8194 - learning_rate: 6.4000e-08
# Epoch 30/30
# 43/43 - 27s - 625ms/step - accuracy: 0.7854 - f1_score: 0.7045 - f1_score0: 0.6367 - f1_score1: 0.6697 - f1_score2: 0.8072 - loss: 0.6068 - m_io_u: 0.4511 - precision: 0.8291 - precision_0: 0.6400 - precision_1: 0.6808 - precision_2: 0.7984 - recall: 0.7392 - recall_0: 0.6424 - recall_1: 0.6693 - recall_2: 0.8181 - val_accuracy: 0.7124 - val_f1_score: 0.6034 - val_f1_score0: 0.4905 - val_f1_score1: 0.5111 - val_f1_score2: 0.8085 - val_loss: 0.7575 - val_m_io_u: 0.4125 - val_precision: 0.7293 - val_precision_0: 0.4327 - val_precision_1: 0.5820 - val_precision_2: 0.8280 - val_recall: 0.6929 - val_recall_0: 0.5662 - val_recall_1: 0.4556 - val_recall_2: 0.7899 - learning_rate: 6.4000e-08

# %%
model.load_weights('model_ckpt/6_res50_16_128.keras')

# %%
x = valid_img_gen.take(1)

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# import tensorflow as tf
from matplotlib.colors import ListedColormap, BoundaryNorm
from matplotlib.patches import Patch
# Assuming model, valid_img_gen are defined, and weights are loaded

fig, axs = plt.subplots(32, 3, figsize=(10, 50))
class_colors = ['#45B39D', '#229954', '#F7DC6F','#145A32']  # Example for 3 classes
custom_cmap = ListedColormap(class_colors)
class_labels = [0, 1, 2,3] 
boundaries = np.arange(min(class_labels) - 0.5, max(class_labels) + 1.5, 1)
norm = BoundaryNorm(boundaries, custom_cmap.N, clip=True)
class_names = ['Flood','Sprinkler','NonIrr']
cnt = 0
legend_handles = [Patch(color=color, label=label) for color, label in zip(class_colors, class_names)]
i=0

for images, labels in x:
    if cnt == 2:
        break
    preds = model.predict(images)
    for j in range(16):
        image = images[j].numpy()
        label = labels[j].numpy()  # Adjusted for direct numpy conversion
        masks = np.argmax(label, axis=-1)
        pred_mask = np.argmax(preds[i], axis=-1)

        # Display the image
        im0 = axs[i][0].imshow(image[:,:,:3])
        # Display the true mask
        im1 = axs[i][1].imshow(masks,cmap=custom_cmap, norm=norm, interpolation='nearest')
        # Display the predicted mask
        im2 = axs[i][2].imshow(pred_mask,cmap=custom_cmap, norm=norm, interpolation='nearest')

        # Remove ticks
        axs[i][0].axis('off')
        axs[i][1].axis('off')
        axs[i][2].axis('off')

        # Add colorbars
        # For the true mask
        fig.colorbar(im1, ax=axs[i][1], fraction=0.046, pad=0.04)
        # For the predicted mask
        fig.colorbar(im2, ax=axs[i][2], fraction=0.046, pad=0.04)
        i=i+1
    cnt = cnt + 1

    break  # Since you have a break here, it only goes through the loop once

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
model.load_weights('model_ckpt/mres50_1.weights.h5')
x = valid_img_gen.take(1)
fig,axs = plt.subplots(16,3,figsize=(10, 50))
for images,labels in x:
    # print(images.shape)
    preds=model.predict(images)
    # print(np.array(preds).shape)
    for i in range(16):
        image = images[i].numpy()
        # image = cv2.normalize(image, None, alpha = 0, beta = 1, norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F)
        print(labels[i].shape)
        masks = np.argmax(labels[i],axis=-1)
        pred_mask = np.argmax(preds[i],axis=-1)
        axs[i][0].imshow(image)
        axs[i][1].imshow(masks)
        axs[i][2].imshow(pred_mask)
    break
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)

# %% [markdown]
# ### Extra

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np




matplotlib.rcParams['font.size'] = 8


def plot_img_and_hist(image, axes, bins=256):
    """Plot an image along with its histogram and cumulative histogram.

    """
    image = img_as_float(image)
    ax_img, ax_hist = axes
    ax_cdf = ax_hist.twinx()

    # Display image
    ax_img.imshow(image, cmap=plt.cm.gray)
    ax_img.set_axis_off()

    # Display histogram
    ax_hist.hist(image.ravel(), bins=bins, histtype='step', color='black')
    ax_hist.ticklabel_format(axis='y', style='scientific', scilimits=(0, 0))
    ax_hist.set_xlabel('Pixel intensity')
    ax_hist.set_xlim(0, 1)
    ax_hist.set_yticks([])

    # Display cumulative distribution
    img_cdf, bins = exposure.cumulative_distribution(image, bins)
    ax_cdf.plot(bins, img_cdf, 'r')
    ax_cdf.set_yticks([])

    return ax_img, ax_hist, ax_cdf


im = iter(training.take(2)).next()
img = im[0].numpy()[0][:,:,0:3]+np.array([0.5,0.6,0.5])
img = normalize_satellite_image(img)
# # Load an example image
# img = data.moon()

# Contrast stretching
p2, p98 = np.percentile(img, (3, 98))
img_rescale = exposure.rescale_intensity(img, in_range=(p2, p98))

# Adaptive Equalization
img_adapteq = exposure.equalize_adapthist(img, clip_limit=0.03)

# Display results
fig = plt.figure(figsize=(8, 5))
axes = np.zeros((2, 4), dtype=object)
axes[0, 0] = fig.add_subplot(2, 4, 1)
for i in range(1, 4):
    axes[0, i] = fig.add_subplot(2, 4, 1+i, sharex=axes[0,0], sharey=axes[0,0])
for i in range(0, 4):
    axes[1, i] = fig.add_subplot(2, 4, 5+i)

ax_img, ax_hist, ax_cdf = plot_img_and_hist(img, axes[:, 0])
ax_img.set_title('Low contrast image')

y_min, y_max = ax_hist.get_ylim()
ax_hist.set_ylabel('Number of pixels')
ax_hist.set_yticks(np.linspace(0, y_max, 5))

ax_img, ax_hist, ax_cdf = plot_img_and_hist(img_rescale, axes[:, 1])
ax_img.set_title('Contrast stretching')

ax_img, ax_hist, ax_cdf = plot_img_and_hist(img_eq, axes[:, 2])
ax_img.set_title('Histogram equalization')

ax_img, ax_hist, ax_cdf = plot_img_and_hist(img_adapteq, axes[:, 3])
ax_img.set_title('Adaptive equalization')

ax_cdf.set_ylabel('Fraction of total intensity')
ax_cdf.set_yticks(np.linspace(0, 1, 5))

# prevent overlap of y-axis labels
fig.tight_layout()
plt.show()
